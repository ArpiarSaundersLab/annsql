# %% [markdown]
# # Advanced Usage
# Using AnnSQL, we will demonstrate extended functionality and how to perform the following operations:
#
# - Determine total counts per cell library
# - Calculate total gene counts
# - Normalize the counts to 10,000 reads per cell.
# - Log transform the counts.
# - Calculate the top 2000 highly variable genes.

# %% [markdown]
# ###  Install the AnnSQL package
#
# ```bash
# pip install annsql
# ```

# %% [markdown]
# ### Import libraries, build, then open the database

# %%
from AnnSQL import AnnSQL
from MakeDb import MakeDb
import scanpy as sc
import os
adata = sc.datasets.pbmc3k()
adata.var_names_make_unique()
if os.path.exists("db/pbmc3k.asql"):
	os.remove("db/pbmc3k.asql")
MakeDb(adata=adata, db_name="pbmc3k", db_path="db/")
adata_sql = AnnSQL(db="db/pbmc3k.asql")
# Out:
# Time to make var_names unique:  18.767115592956543
# Time to create X table schema:  0.24080705642700195
# Time to insert X data:  9.258856296539307

# %% [markdown]
# ### Calculate total counts per cell

# %%
adata_sql.calculate_total_counts(chunk_size=950) #if system memory is low, lower chunks to <=200
# Out:
# Total Counts Calculation Started
# Total Counts Calculation Complete

# %% [markdown]
# ### View the total counts

# %%
adata_sql.query("SELECT total_counts FROM X ORDER BY total_counts DESC LIMIT 5 ")
# Out:
#    total_counts
# 0       15844.0
# 1       15301.0
# 2       10783.0
# 3       10359.0
# 4       10282.0

# %% [markdown]
# ### Calculate counts per gene

# %%
adata_sql.calculate_gene_counts(chunk_size=950)
# Out:
# Updating Var Table
# Update Query Error: Binder Error: Table "var" does not have a column with name "gene_counts"
# Gene Counts Calculation Started
# Gene Counts Calculation Complete

# %% [markdown]
# ### View the gene counts

# %%
adata_sql.query("SELECT * FROM var ORDER BY gene_counts DESC LIMIT 5 ")
# Out:
#           gene_ids gene_names_orig gene_names  gene_counts
# 0  ENSG00000251562          MALAT1     MALAT1     161685.0
# 1  ENSG00000205542          TMSB4X     TMSB4X     124210.0
# 2  ENSG00000166710             B2M        B2M     121363.0
# 3  ENSG00000147403           RPL10      RPL10      88517.0
# 4  ENSG00000167526           RPL13      RPL13      77111.0

# %% [markdown]
# ### Normalize cell expression counts to 10,000

# %%
#lower chunk_size if system memory is low. Max supported chunk_size is 950 (DuckDB limitation)
adata_sql.expression_normalize(chunk_size=950)
# Out:
# Expression Normalization Started
# Expression Normalization Complete

# %% [markdown]
# ### View a normalized gene

# %%
adata_sql.query("SELECT RER1 FROM X ORDER BY RER1 DESC LIMIT 5 ")
# Out:
#          RER1
# 0  219.324249
# 1  204.081635
# 2   35.587189
# 3   18.939394
# 4   17.401392

# %% [markdown]
# ### Log transform the expression values

# %%
adata_sql.expression_log(log_type="LOG2", chunk_size=950) #LOG2 or LOG10
# Out:
# Log Transform Started
# Log Transform Complete

# %% [markdown]
# ### Examine a log transformed value

# %%
adata_sql.query("SELECT RER1 FROM X ORDER BY RER1 DESC LIMIT 5 ")
# Out:
#        RER1
# 0  7.776922
# 1  7.673003
# 2  5.153286
# 3  4.243319
# 4  4.121131

# %% [markdown]
# ### Calculate Highly Variable Genes

# %%
adata_sql.calculate_variable_genes(chunk_size=950)
# Out:
# Updating Var Table
# Update Query Error: Binder Error: Table "var" does not have a column with name "variance"
# Variance Calculation Complete

# %% [markdown]
# ### View the top 50 highly variable genes

# %%
adata_sql.query("SELECT * FROM var ORDER BY variance DESC LIMIT 50 ")
# Out:
#            gene_ids gene_names_orig gene_names  gene_counts    variance
# 0   ENSG00000204287         HLA-DRA    HLA_DRA      16467.0  111.171577
# 1   ENSG00000011600          TYROBP     TYROBP       9381.0  107.384903
# 2   ENSG00000101439            CST3       CST3      11857.0  107.361053
# 3   ENSG00000090382             LYZ        LYZ      27666.0  107.279701
# 4   ENSG00000100097          LGALS1     LGALS1       8055.0  106.759933
# 5   ENSG00000163220          S100A9     S100A9      16326.0  105.228394
# 6   ENSG00000223865        HLA-DPB1   HLA_DPB1       7817.0  104.762688
# 7   ENSG00000196126        HLA-DRB1   HLA_DRB1       6829.0  104.746109
# 8   ENSG00000231389        HLA-DPA1   HLA_DPA1       6980.0  104.061783
# 9   ENSG00000008517            IL32       IL32       5708.0  102.100822
# 10  ENSG00000163131            CTSS       CTSS       5466.0   99.912094
# 11  ENSG00000167286            CD3D       CD3D       4000.0   99.723969
# 12  ENSG00000163191         S100A11    S100A11       5246.0   99.707069
# 13  ENSG00000130066            SAT1       SAT1       7425.0   99.053444
# 14  ENSG00000204472            AIF1       AIF1       6090.0   98.495972
# 15  ENSG00000197746            PSAP       PSAP       4609.0   98.351776
# 16  ENSG00000158869          FCER1G     FCER1G       5498.0   96.815857
# 17  ENSG00000084207           GSTP1      GSTP1       3672.0   96.735641
# 18  ENSG00000204482            LST1       LST1       5863.0   96.373497
# 19  ENSG00000198851            CD3E       CD3E       2831.0   95.801888
# 20  ENSG00000103187           COTL1      COTL1       8075.0   95.578957
# 21  ENSG00000122862            SRGN       SRGN       5112.0   95.219879
# 22  ENSG00000233276            GPX1       GPX1       3471.0   95.109932
# 23  ENSG00000170296         GABARAP    GABARAP       2928.0   94.991829
# 24  ENSG00000187608           ISG15      ISG15       3228.0   94.770676
# 25  ENSG00000121966           CXCR4      CXCR4       4140.0   94.498955
# 26  ENSG00000100906          NFKBIA     NFKBIA       2753.0   94.257256
# 27  ENSG00000179144          GIMAP7     GIMAP7       3007.0   94.175827
# 28  ENSG00000135046           ANXA1      ANXA1       4273.0   94.039459
# 29  ENSG00000126264            HCST       HCST       2848.0   94.032143
# 30  ENSG00000161570            CCL5       CCL5       5491.0   94.020805
# 31  ENSG00000185885          IFITM1     IFITM1       2407.0   93.897545
# 32  ENSG00000100300            TSPO       TSPO       2651.0   93.870689
# 33  ENSG00000002586            CD99       CD99       2414.0   93.533203
# 34  ENSG00000119655            NPC2       NPC2       3129.0   93.491676
# 35  ENSG00000188404            SELL       SELL       2351.0   93.341553
# 36  ENSG00000104964             AES        AES       2377.0   93.321999
# 37  ENSG00000145287           PLAC8      PLAC8       2454.0   93.205070
# 38  ENSG00000158710          TAGLN2     TAGLN2       2588.0   93.193192
# 39  ENSG00000005022         SLC25A5    SLC25A5       2728.0   93.192123
# 40  ENSG00000196405             EVL        EVL       2572.0   93.099823
# 41  ENSG00000111669            TPI1       TPI1       2625.0   93.011688
# 42  ENSG00000143933           CALM2      CALM2       2821.0   92.932571
# 43  ENSG00000182718           ANXA2      ANXA2       2724.0   92.924889
# 44  ENSG00000160255           ITGB2      ITGB2       2431.0   92.917213
# 45  ENSG00000162704           ARPC5      ARPC5       2691.0   92.878304
# 46  ENSG00000100911           PSME2      PSME2       2964.0   92.866951
# 47  ENSG00000169230         PRELID1    PRELID1       2579.0   92.853233
# 48  ENSG00000133321         RARRES3    RARRES3       2274.0   92.678169
# 49  ENSG00000204387         C6orf48    C6orf48       2676.0   92.676727

# %%
#perform the same using the adata object
# sc.pp.normalize_total(adata, target_sum=1e4)
# sc.pp.log1p(adata)
# sc.pp.highly_variable_genes(adata, n_top_genes=50, subset=True)
adata.var
# Out:
#                      gene_ids gene_names_orig    gene_names  highly_variable  \
# index
# LRRIQ3        ENSG00000162620          LRRIQ3        LRRIQ3             True
# C2CD4D        ENSG00000225556          C2CD4D        C2CD4D             True
# UBE2Q1        ENSG00000160714          UBE2Q1        UBE2Q1             True
# KIF3C         ENSG00000084731           KIF3C         KIF3C             True
# FAM98A        ENSG00000119812          FAM98A        FAM98A             True
# MTIF2         ENSG00000085760           MTIF2         MTIF2             True
# TTN-AS1       ENSG00000237298         TTN-AS1       TTN_AS1             True
# HEMK1         ENSG00000114735           HEMK1         HEMK1             True
# LINC00886     ENSG00000240875       LINC00886     LINC00886             True
# IDUA          ENSG00000127415            IDUA          IDUA             True
# ARHGAP24      ENSG00000138639        ARHGAP24      ARHGAP24             True
# USP38         ENSG00000170185           USP38         USP38             True
# MOCS2         ENSG00000164172           MOCS2         MOCS2             True
# CTB-113I20.2  ENSG00000271737    CTB-113I20.2  CTB_113I20_2             True
# RNF14         ENSG00000013561           RNF14         RNF14             True
# DOK3          ENSG00000146094            DOK3          DOK3             True
# HIST1H1B      ENSG00000184357        HIST1H1B      HIST1H1B             True
# PPT2-EGFL8    ENSG00000258388      PPT2-EGFL8    PPT2_EGFL8             True
# ABCC10        ENSG00000124574          ABCC10        ABCC10             True
# UBE2D4        ENSG00000078967          UBE2D4        UBE2D4             True
# GJC3          ENSG00000176402            GJC3          GJC3             True
# CTB-152G17.6  ENSG00000272918    CTB-152G17.6  CTB_152G17_6             True
# TMEM140       ENSG00000146859         TMEM140       TMEM140             True
# KIAA0196      ENSG00000164961        KIAA0196      KIAA0196             True
# CDKN2A        ENSG00000147889          CDKN2A        CDKN2A             True
# ABHD17B       ENSG00000107362         ABHD17B       ABHD17B             True
# GBGT1         ENSG00000148288           GBGT1         GBGT1             True
# LZTS2         ENSG00000107816           LZTS2         LZTS2             True
# KCNQ1OT1      ENSG00000269821        KCNQ1OT1      KCNQ1OT1             True
# TAF10         ENSG00000166337           TAF10         TAF10             True
# MICALCL       ENSG00000133808         MICALCL       MICALCL             True
# MADD          ENSG00000110514            MADD          MADD             True
# PGM2L1        ENSG00000165434          PGM2L1        PGM2L1             True
# MTRF1         ENSG00000120662           MTRF1         MTRF1             True
# RAD51B        ENSG00000182185          RAD51B        RAD51B             True
# CEP128        ENSG00000100629          CEP128        CEP128             True
# TTC8          ENSG00000165533            TTC8          TTC8             True
# DPH6          ENSG00000134146            DPH6          DPH6             True
# MGA           ENSG00000174197             MGA           MGA             True
# TADA2A        ENSG00000108264          TADA2A        TADA2A             True
# YPEL2         ENSG00000175155           YPEL2         YPEL2             True
# PXMP4         ENSG00000101417           PXMP4         PXMP4             True
# FAM210B       ENSG00000124098         FAM210B       FAM210B             True
# ZNF561        ENSG00000171469          ZNF561        ZNF561             True
# SLC27A1       ENSG00000130304         SLC27A1       SLC27A1             True
# LINC00662     ENSG00000261824       LINC00662     LINC00662             True
# EID2          ENSG00000176396            EID2          EID2             True
# NAPA-AS1      ENSG00000268061        NAPA-AS1      NAPA_AS1             True
# ARVCF         ENSG00000099889           ARVCF         ARVCF             True
# BACE2         ENSG00000182240           BACE2         BACE2             True
#
#                  means  dispersions  dispersions_norm
# index
# LRRIQ3        3.213468     9.071757         -0.243689
# C2CD4D        2.543835     8.961646          1.000000
# UBE2Q1        5.034218     9.036189          1.347446
# KIF3C         2.837004     8.877491         -0.152070
# FAM98A        4.404673     8.917180         -1.079913
# MTIF2         5.158188     8.983418          0.010936
# TTN-AS1       4.378264     9.023237          1.749578
# HEMK1         4.822398     9.000399          0.707107
# LINC00886     2.971364     8.985250          1.067325
# IDUA          3.791737     8.956385          1.000000
# ARHGAP24      5.390102     8.968667         -0.941134
# USP38         4.957004     8.925668         -1.242990
# MOCS2         5.525486     9.006554          0.707107
# CTB-113I20.2  3.391272     8.975166          1.000000
# RNF14         5.316161     8.975213          1.049963
# DOK3          5.298748     8.992214          0.290030
# HIST1H1B      2.896015     8.810048         -0.915255
# PPT2-EGFL8    1.782865     8.431535          1.000000
# ABCC10        4.280816     8.959032          0.036648
# UBE2D4        5.085014     8.945298         -0.782899
# GJC3          1.548350     9.210341               NaN
# CTB-152G17.6  3.090179     9.025933         -0.855633
# TMEM140       5.321552     8.971403         -0.108829
# KIAA0196      5.191907     8.984737          0.052788
# CDKN2A        4.202718     8.929900         -0.707107
# ABHD17B       4.962672     9.011206          0.761884
# GBGT1         4.350966     8.908219         -1.318975
# LZTS2         3.509062     9.012050         -0.707107
# KCNQ1OT1      5.298806     8.955911         -0.861797
# TAF10         5.727251     8.932841         -0.707107
# MICALCL       1.548350     9.210341               NaN
# MADD          5.178847     8.975141         -0.251673
# PGM2L1        4.788481     8.983497         -0.707107
# MTRF1         4.463637     8.987779          0.803594
# RAD51B        4.496681     8.997377          0.707107
# CEP128        3.571444     9.066368          0.707107
# TTC8          2.245905     8.372250          1.000000
# DPH6          5.049900     8.999710          0.492446
# MGA           5.136610     9.023810          1.292503
# TADA2A        4.288037     8.946626         -0.294318
# YPEL2         4.966999     8.935684         -1.008236
# PXMP4         4.628400     8.938475         -0.707107
# FAM210B       5.249617     8.928492         -1.731734
# ZNF561        4.973300     8.997146          0.432349
# SLC27A1       4.412627     8.973967          0.435097
# LINC00662     5.162801     9.020862          1.198948
# EID2          4.004142     9.055838          1.000000
# NAPA-AS1      4.150572     8.939908          0.707107
# ARVCF         3.017711     9.172325          1.099322
# BACE2         4.419966     8.945224         -0.331712

# %%
method1 = adata_sql.query("SELECT gene_names_orig FROM var ORDER BY variance DESC LIMIT 50").values.flatten()
method2 = adata.var.gene_names_orig.values

#find which genes are common between the two methods
common_genes = set(method1).intersection(set(method2))
# Out:
# array(['LRRIQ3', 'C2CD4D', 'UBE2Q1', 'KIF3C', 'FAM98A', 'MTIF2',
#        'TTN-AS1', 'HEMK1', 'LINC00886', 'IDUA', 'ARHGAP24', 'USP38',
#        'MOCS2', 'CTB-113I20.2', 'RNF14', 'DOK3', 'HIST1H1B', 'PPT2-EGFL8',
#        'ABCC10', 'UBE2D4', 'GJC3', 'CTB-152G17.6', 'TMEM140', 'KIAA0196',
#        'CDKN2A', 'ABHD17B', 'GBGT1', 'LZTS2', 'KCNQ1OT1', 'TAF10',
#        'MICALCL', 'MADD', 'PGM2L1', 'MTRF1', 'RAD51B', 'CEP128', 'TTC8',
#        'DPH6', 'MGA', 'TADA2A', 'YPEL2', 'PXMP4', 'FAM210B', 'ZNF561',
#        'SLC27A1', 'LINC00662', 'EID2', 'NAPA-AS1', 'ARVCF', 'BACE2'],
#       dtype=object)
